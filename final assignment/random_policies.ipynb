# %%
from ema_workbench import load_results
from ema_workbench import (Model, RealParameter, ScalarOutcome, MultiprocessingEvaluator, 
                           ema_logging, Constant, Scenario, Policy, CategoricalParameter, IntegerParameter,
                           perform_experiments, SequentialEvaluator)

from ema_workbench.em_framework.evaluators import perform_experiments
from ema_workbench.em_framework.samplers import sample_uncertainties
from ema_workbench.util import ema_logging, utilities
import time

ema_logging.log_to_stderr(ema_logging.INFO)

from dike_model_function import DikeNetwork
from custom_problem_formulation import get_model_for_problem_formulation

# %%
dike_model,  planning_steps = get_model_for_problem_formulation(3)

with MultiprocessingEvaluator(dike_model) as evaluator:
    results = evaluator.perform_experiments(scenarios=400, policies=100)

utilities.save_results(results, './results/random_policies.tar.gz')
# Out:
# /Users/wouter/.pyenv/versions/3.12.2/envs/EPA141A_Model_Based_Decision_Making_Env/lib/python3.12/site-packages/ema_workbench/em_framework/__init__.py:101: UserWarning: ipyparallel not installed - IpyparalleEvaluator not available
#   warnings.warn("ipyparallel not installed - IpyparalleEvaluator not available")
# /Users/wouter/.pyenv/versions/3.12.2/envs/EPA141A_Model_Based_Decision_Making_Env/lib/python3.12/site-packages/ema_workbench/em_framework/__init__.py:101: UserWarning: ipyparallel not installed - IpyparalleEvaluator not available
#   warnings.warn("ipyparallel not installed - IpyparalleEvaluator not available")
# /Users/wouter/.pyenv/versions/3.12.2/envs/EPA141A_Model_Based_Decision_Making_Env/lib/python3.12/site-packages/ema_workbench/em_framework/__init__.py:101: UserWarning: ipyparallel not installed - IpyparalleEvaluator not available
#   warnings.warn("ipyparallel not installed - IpyparalleEvaluator not available")
# /Users/wouter/.pyenv/versions/3.12.2/envs/EPA141A_Model_Based_Decision_Making_Env/lib/python3.12/site-packages/ema_workbench/em_framework/__init__.py:101: UserWarning: ipyparallel not installed - IpyparalleEvaluator not available
#   warnings.warn("ipyparallel not installed - IpyparalleEvaluator not available")
#
# /Users/wouter/.pyenv/versions/3.12.2/envs/EPA141A_Model_Based_Decision_Making_Env/lib/python3.12/site-packages/ema_workbench/em_framework/__init__.py:101: UserWarning: ipyparallel not installed - IpyparalleEvaluator not available
#   warnings.warn("ipyparallel not installed - IpyparalleEvaluator not available")
# /Users/wouter/.pyenv/versions/3.12.2/envs/EPA141A_Model_Based_Decision_Making_Env/lib/python3.12/site-packages/ema_workbench/em_framework/__init__.py:101: UserWarning: ipyparallel not installed - IpyparalleEvaluator not available
#   warnings.warn("ipyparallel not installed - IpyparalleEvaluator not available")
# /Users/wouter/.pyenv/versions/3.12.2/envs/EPA141A_Model_Based_Decision_Making_Env/lib/python3.12/site-packages/ema_workbench/em_framework/__init__.py:101: UserWarning: ipyparallel not installed - IpyparalleEvaluator not available
#   warnings.warn("ipyparallel not installed - IpyparalleEvaluator not available")
# /Users/wouter/.pyenv/versions/3.12.2/envs/EPA141A_Model_Based_Decision_Making_Env/lib/python3.12/site-packages/ema_workbench/em_framework/__init__.py:101: UserWarning: ipyparallel not installed - IpyparalleEvaluator not available
#   warnings.warn("ipyparallel not installed - IpyparalleEvaluator not available")
# [MainProcess/INFO] pool started with 8 workers
# [MainProcess/INFO] performing 400 scenarios * 100 policies * 1 model(s) = 40000 experiments
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [MainProcess/INFO] terminating pool
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 4
#       1 dike_model,  planning_steps = get_model_for_problem_formulation(3)
#       3 with MultiprocessingEvaluator(dike_model) as evaluator:
# ----> 4     results = evaluator.perform_experiments(scenarios=400, policies=100)
#       6 utilities.save_results(results, './results/random_policies.tar.gz')
#
# File ~/.pyenv/versions/3.12.2/envs/EPA141A_Model_Based_Decision_Making_Env/lib/python3.12/site-packages/ema_workbench/em_framework/evaluators.py:193, in BaseEvaluator.perform_experiments(self, scenarios, policies, reporting_interval, reporting_frequency, uncertainty_union, lever_union, outcome_union, uncertainty_sampling, lever_sampling, callback, combine, **kwargs)
#     172 def perform_experiments(
#     173     self,
#     174     scenarios=0,
#    (...)
#     185     **kwargs,
#     186 ):
#     187     """convenience method for performing experiments.
#     188
#     189     is forwarded to :func:perform_experiments, with evaluator and
#     190     models arguments added in.
#     191
#     192     """
# --> 193     return perform_experiments(
#     194         self._msis,
#     195         scenarios=scenarios,
#     196         policies=policies,
#     197         evaluator=self,
#     198         reporting_interval=reporting_interval,
#     199         reporting_frequency=reporting_frequency,
#     200         uncertainty_union=uncertainty_union,
#     201         lever_union=lever_union,
#     202         outcome_union=outcome_union,
#     203         uncertainty_sampling=uncertainty_sampling,
#     204         lever_sampling=lever_sampling,
#     205         callback=callback,
#     206         combine=combine,
#     207         **kwargs,
#     208     )
#
# File ~/.pyenv/versions/3.12.2/envs/EPA141A_Model_Based_Decision_Making_Env/lib/python3.12/site-packages/ema_workbench/em_framework/evaluators.py:406, in perform_experiments(models, scenarios, policies, evaluator, reporting_interval, reporting_frequency, uncertainty_union, lever_union, outcome_union, uncertainty_sampling, lever_sampling, callback, return_callback, combine, log_progress, **kwargs)
#     403 if not evaluator:
#     404     evaluator = SequentialEvaluator(models)
# --> 406 evaluator.evaluate_experiments(scenarios, policies, callback, combine=combine, **kwargs)
#     408 if callback.i != nr_of_exp:
#     409     raise EMAError(
#     410         f"Some fatal error has occurred while running the experiments, not all runs have completed. Expected {nr_of_exp}, got {callback.i}"
#     411     )
#
# File ~/.pyenv/versions/3.12.2/envs/EPA141A_Model_Based_Decision_Making_Env/lib/python3.12/site-packages/ema_workbench/em_framework/futures_multiprocessing.py:320, in MultiprocessingEvaluator.evaluate_experiments(self, scenarios, policies, callback, combine)
#     318 def evaluate_experiments(self, scenarios, policies, callback, combine="factorial"):
#     319     ex_gen = experiment_generator(scenarios, self._msis, policies, combine=combine)
# --> 320     add_tasks(self.n_processes, self._pool, ex_gen, callback)
#
# File ~/.pyenv/versions/3.12.2/envs/EPA141A_Model_Based_Decision_Making_Env/lib/python3.12/site-packages/ema_workbench/em_framework/futures_multiprocessing.py:225, in add_tasks(n_processes, pool, experiments, callback)
#     222 feeder.start()
#     223 reader.start()
# --> 225 feeder.join()
#     226 results_queue.put(None)
#     227 reader.join()
#
# File ~/.pyenv/versions/3.12.2/lib/python3.12/threading.py:1147, in Thread.join(self, timeout)
#    1144     raise RuntimeError("cannot join current thread")
#    1146 if timeout is None:
# -> 1147     self._wait_for_tstate_lock()
#    1148 else:
#    1149     # the behavior of a negative timeout isn't documented, but
#    1150     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1151     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~/.pyenv/versions/3.12.2/lib/python3.12/threading.py:1167, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1164     return
#    1166 try:
# -> 1167     if lock.acquire(block, timeout):
#    1168         lock.release()
#    1169         self._stop()
#
# KeyboardInterrupt:
